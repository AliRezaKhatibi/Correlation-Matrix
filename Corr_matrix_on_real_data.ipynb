# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def compute_correlation_matrix(*vectors):
    """
    Compute the correlation matrix for the given input vectors.
    :param vectors: Multiple input vectors
    :return: Correlation matrix
    """
    matrix = np.column_stack((vectors))  # Create a matrix from the input vectors
    correlation_matrix = np.corrcoef(matrix, rowvar=False)  # Compute correlation matrix
    return correlation_matrix




def determinant(matrix):
    """
    Compute the determinant of a matrix using NumPy.
    :param matrix: Square matrix
    :return: Determinant of the matrix
    """
    return np.linalg.det(matrix)

# %%
data = pd.read_csv("height_weight_bmi_with_age.csv")
data
# Out:
#     Height (m)  Height (cm)  Height (mm)  Weight (kg)    Weight (g)  \
# 0     1.687270   168.727006  1687.270059    51.571459  51571.459284
# 1     1.975357   197.535715  1975.357153    81.820521  81820.520563
# 2     1.865997   186.599697  1865.996971    65.717799  65717.799054
# 3     1.799329   179.932924  1799.329242    75.428535  75428.534558
# 4     1.578009   157.800932  1578.009320    95.378324  95378.323696
# ..         ...          ...          ...          ...           ...
# 95    1.746898   174.689780  1746.897798    67.460479  67460.478731
# 96    1.761366   176.136641  1761.366415    86.297784  86297.783944
# 97    1.713771   171.377051  1713.770509    94.855513  94855.512998
# 98    1.512710   151.270956  1512.709563    94.354321  94354.321213
# 99    1.553946   155.394571  1553.945713    88.993777  88993.777293
#
#           BMI  Random Value  Age
# 0   18.115079     67.782848   62
# 1   20.968675     17.572597   49
# 2   18.873878     24.546584   69
# 3   23.297772     90.869877   47
# 4   38.302803     64.578615   64
# ..        ...           ...  ...
# 95  22.106217     57.001893   68
# 96  27.816355     79.299420   60
# 97  32.296633     29.423892   54
# 98  41.233546     66.060143   29
# 99  36.854282     17.681272   20
#
# [100 rows x 8 columns]

# %%
# data
x_1 = data["Height (m)"]
x_2 = data["Height (cm)"]
x_3 = data["Height (mm)"]




correlation_matrix = compute_correlation_matrix(x_1,x_2,x_3)
det = determinant(correlation_matrix)

print("Correlation Matrix:")
print(correlation_matrix)
print("Determinant of the Correlation Matrix:", round(det, 4))
# Print determinant of the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", cbar=True, vmin=-1, vmax=+1)
plt.title("Correlation Matrix Heatmap")
plt.show()
# Out:
# Correlation Matrix:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]
# Determinant of the Correlation Matrix: 0.0

# %%
# data
x_1 = data["Height (cm)"]
x_2 = data["Weight (kg)"]
x_3 = data["Age"]


correlation_matrix = compute_correlation_matrix(x_1,x_2,x_3)
det = determinant(correlation_matrix)

print("Correlation Matrix:")
print(correlation_matrix)
print("Determinant of the Correlation Matrix:", round(det, 4))
# Print determinant of the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", cbar=True, vmin=-1, vmax=+1)
plt.title("Correlation Matrix Heatmap")
plt.show()
# Out:
# Correlation Matrix:
# [[ 1.         -0.0340325   0.15755957]
#  [-0.0340325   1.          0.08503311]
#  [ 0.15755957  0.08503311  1.        ]]
# Determinant of the Correlation Matrix: 0.9659

# %%
# finish
